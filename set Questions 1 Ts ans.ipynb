# %%
import pandas as pd
date = pd.date_range(start='2023-01-01',periods=10, freq='MS')
df = pd.DataFrame({'Date': ['2023-01-01', '2023-01-02', '2023-01-03'],
                   'Sales': [100, 120, 130]})

pd.isnull(df['Sales']).sum()
df['7_day_avg'] = df['Sales'].rolling(window=7).mean()
print(df)
# Out:
#          Date  Sales  7_day_avg
# 0  2023-01-01    100        NaN
# 1  2023-01-02    120        NaN
# 2  2023-01-03    130        NaN

# %%
import pandas as pd

df = pd.DataFrame({'Date': ['2023-01-01', '2023-01-02', '2023-01-03'],
                   'Sales': [100, 120, 130]})
df['7_day_avg'] = df['Sales'].rolling(window=7, min_periods=1).mean()
print(df)
# Out:
#          Date  Sales   7_day_avg
# 0  2023-01-01    100  100.000000
# 1  2023-01-02    120  110.000000
# 2  2023-01-03    130  116.666667

# %%
from statsmodels.tsa.arima.model import ARIMA

print(df.columns)
if 'Temp' in df.columns:
    value = df['Temp']
else:
    print("Column'Temp' is missing.")
if 'Temp' in df.columns:
    model = ARIMA(df['Temp'], order=(1,1,1))
else:
    print("Column'Temp' not found. Available columns:",df.columns)
# Out:
# Index(['Passengers'], dtype='str')
# Column'Temp' is missing.
# Column'Temp' not found. Available columns: Index(['Passengers'], dtype='str')

# %%
import pandas as pd
import numpy as np
data = {
    'Date': pd.date_range(start='2023-01-01', periods=10, freq='D'),
    'Passengers': [100, 120, np.nan, 140, 135, np.nan, 150, 160, 170, np.nan]
}

df = pd.DataFrame(data)
print("Original Data:\n", df)
df['Passengers'] = df['Passengers'].fillna(0).astype(int)
# Out:
# Original Data:
#          Date  Passengers
# 0 2023-01-01       100.0
# 1 2023-01-02       120.0
# 2 2023-01-03         NaN
# 3 2023-01-04       140.0
# 4 2023-01-05       135.0
# 5 2023-01-06         NaN
# 6 2023-01-07       150.0
# 7 2023-01-08       160.0
# 8 2023-01-09       170.0
# 9 2023-01-10         NaN

# %%
if 'date' in df.columns:
    df['date'] = pd.to_datetime(df['date'])
else:
    print("Column 'date' not found.Available columns:", df.columns)
# Out:
# Column 'date' not found.Available columns: Index(['MonthStart', 'Sales', 'Revenue', 'Expenses'], dtype='str')

# %%
print(df.columns)  # Check column names
df['Date'] = pd.to_datetime(df['Date'])  # Use correct case
# Out:
# Index(['Date', 'Passengers'], dtype='str')

# %%
import pandas as pd
import numpy as np

# Generate monthly start dates for one year
dates=pd.date_range(start='2020-01-01', periods=12, freq='MS')


# Create random data for the time series
data = {
    'MonthStart': dates,
    'Sales': np.random.randint(100, 500, size=12),
    'Revenue': np.random.randint(1000, 5000, size=12),
    'Expenses': np.random.randint(500, 2000, size=12)
}

# Create DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#    MonthStart  Sales  Revenue  Expenses
# 0  2020-01-01    264     4517      1776
# 1  2020-02-01    465     1250       535
# 2  2020-03-01    355     1514      1107
# 3  2020-04-01    357     4879       681
# 4  2020-05-01    243     1409      1788
# 5  2020-06-01    449     4707      1500
# 6  2020-07-01    203     4502      1385
# 7  2020-08-01    431     4373      1672
# 8  2020-09-01    225     3765      1807
# 9  2020-10-01    455     4848      1599
# 10 2020-11-01    386     4245      1941
# 11 2020-12-01    254     3301       924

# %%
data = pd.read_csv('daily_sales.csv')  # Remove squeeze

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# Load dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv'
df = pd.read_csv(url, header=0, parse_dates=['Month'], index_col='Month')

# Fit ARIMA model
model = ARIMA(df['Passengers'], order=(5, 1, 0))
model_fit = model.fit()

# Forecast next 12 time steps
forecast = model_fit.forecast(steps=12)
# Out:
# C:\Users\Admin\anaconda3\envs\aitd\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\envs\aitd\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\envs\aitd\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# Load dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv'
df = pd.read_csv(url, header=0, parse_dates=['Month'], index_col='Month')

# Fit ARIMA model
model = ARIMA(df['Passengers'], order=(5, 1, 0))
model_fit = model.fit()

# Forecast next 12 time steps
forecast = model_fit.forecast(steps=12)
# Out:
# C:\Users\Admin\anaconda3\envs\aitd\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\envs\aitd\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\envs\aitd\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
forecast = model_fit.forecast(steps=12)
plt.plot(forecast)
plt.show()
