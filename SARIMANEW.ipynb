# %%
import pandas as pd

# %%
#https://machinelearningmastery.com/time-series-forecasting-methods-in-python-cheat-sheet/

# %%
dataset=pd.read_csv("Airmean_chennai.csv")

# %%
dataset
# Out:
#             Date     City      PM2.5        PM10     NO    NO2    NOx    NH3  \
# 0     2015-01-01  Chennai  77.394417  149.388739  16.30  15.39  22.68   4.59
# 1     2015-01-02  Chennai  77.394417  149.388739  16.49  13.42  23.09   7.83
# 2     2015-01-03  Chennai  77.394417  149.388739   9.72  19.56   9.99   4.63
# 3     2015-01-04  Chennai  77.394417  149.388739   9.60  16.20  11.71   5.23
# 4     2015-01-05  Chennai  77.394417  149.388739   9.16  16.30  12.94   5.50
# ...          ...      ...        ...         ...    ...    ...    ...    ...
# 2004  2020-06-27  Chennai  26.420000   83.998141   7.25  12.96  19.59  33.20
# 2005  2020-06-28  Chennai  25.930000   83.998141   7.81  10.00  16.39  35.98
# 2006  2020-06-29  Chennai  21.300000   83.998141   7.65   9.69  16.74  34.07
# 2007  2020-06-30  Chennai  24.140000   83.998141   8.42  12.38  20.29  34.17
# 2008  2020-07-01  Chennai  15.950000   83.998141   6.22  10.72  16.44  33.52
#
#         CO    SO2        O3   Benzene   Toluene    Xylene         AQI
# 0     1.17   9.20  11.35000  0.170000  7.402406  1.197632  170.088957
# 1     1.23   8.61   9.16000  0.130000  7.402406  1.197632  170.088957
# 2     0.77  20.56  13.45000  0.030000  7.402406  1.197632  170.088957
# 3     1.00  20.56  10.33000  2.120333  7.402406  1.197632  170.088957
# 4     0.90  16.60   9.36000  2.120333  7.402406  1.197632  170.088957
# ...    ...    ...       ...       ...       ...       ...         ...
# 2004  1.10   7.29  68.51000  0.100000  0.070000  1.197632   95.000000
# 2005  0.76   6.48  72.40625  0.090000  0.000000  1.197632   98.000000
# 2006  0.96   6.62  62.57000  0.090000  0.010000  1.197632  104.000000
# 2007  1.05   7.50  68.75000  0.170000  0.160000  1.197632  110.000000
# 2008  1.02   9.23  48.37000  0.090000  0.000000  1.197632   92.000000
#
# [2009 rows x 15 columns]

# %%
dataset["City"].value_counts()
# Out:
# City
# Chennai    2009
# Name: count, dtype: int64

# %%
dataset.isnull().sum()
# Out:
# Date       0
# City       0
# PM2.5      0
# PM10       0
# NO         0
# NO2        0
# NOx        0
# NH3        0
# CO         0
# SO2        0
# O3         0
# Benzene    0
# Toluene    0
# Xylene     0
# AQI        0
# dtype: int64

# %%
timedata=pd.DataFrame()

# %%
timedata["Date"]=dataset["Date"]
timedata["AQI"]=dataset["AQI"]

# %%
timedata
# Out:
#             Date         AQI
# 0     2015-01-01  170.088957
# 1     2015-01-02  170.088957
# 2     2015-01-03  170.088957
# 3     2015-01-04  170.088957
# 4     2015-01-05  170.088957
# ...          ...         ...
# 2004  2020-06-27   95.000000
# 2005  2020-06-28   98.000000
# 2006  2020-06-29  104.000000
# 2007  2020-06-30  110.000000
# 2008  2020-07-01   92.000000
#
# [2009 rows x 2 columns]

# %%
data=timedata["AQI"]

# %%
data_train=data.head(1500)

# %%
data_test=data.tail(509)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model = SARIMAX(data_train, order=(1,1,1), seasonal_order=(0,0,0,0))#Seasonal Autoregressive Integrated Moving Average (ARIMA)
model_fit = model.fit()
# make prediction
y_pred= model_fit.predict(len(data_train), len(data)-1)
print(y_pred)
from sklearn.metrics import r2_score
r2=r2_score(data_test,y_pred)
print("r2={}".format(r2))
# Out:
# 1500    101.526720
# 1501    110.106999
# 1502    115.174982
# 1503    118.168411
# 1504    119.936495
#            ...
# 2004    122.487709
# 2005    122.487709
# 2006    122.487709
# 2007    122.487709
# 2008    122.487709
# Name: predicted_mean, Length: 509, dtype: float64
# r2=-0.6459179353783089

# %%
trends=['n','t','c','ct']
orders=[(0,0,0),(0,0,1),(2,0,1),(1,1,1)]
orderslist=[]
trendslist=[]
rscorelist=[]
for td in trends:
    for i in orders:
        trendslist.append(td)
        orderslist.append(i)
        from statsmodels.tsa.statespace.sarimax import SARIMAX
        model = SARIMAX(data_train, order=i, seasonal_order=(0, 0, 0, 0), trend=td)
        model_fit = model.fit()
    # make prediction
        y_pred= model_fit.predict(len(data_train), len(data)-1)
        print(y_pred)
        from sklearn.metrics import r2_score
        r2=r2_score(data_test,y_pred)
        rscorelist.append(r2)
        print("Trend={}, Order={} ,r2={}".format(td,i,r2))
# Out:
# 1500    0.0
# 1501    0.0
# 1502    0.0
# 1503    0.0
# 1504    0.0
#        ...
# 2004    0.0
# 2005    0.0
# 2006    0.0
# 2007    0.0
# 2008    0.0
# Name: predicted_mean, Length: 509, dtype: float64
# Trend=n, Order=(0, 0, 0) ,r2=-6.410263024207206
# 1500    22.87763
# 1501     0.00000
# 1502     0.00000
# 1503     0.00000
# 1504     0.00000
#           ...
# 2004     0.00000
# 2005     0.00000
# 2006     0.00000
# 2007     0.00000
# 2008     0.00000
# Name: predicted_mean, Length: 509, dtype: float64
# Trend=n, Order=(0, 0, 1) ,r2=-6.405887104311597
# 1500    101.286227
# 1501    109.713793
# 1502    114.682668
# 1503    117.609687
# 1504    119.331286
#            ...
# 2004    114.287230
# 2005    114.272613
# 2006    114.257999
# 2007    114.243386
# 2008    114.228774
# Name: predicted_mean, Length: 509, dtype: float64
# Trend=n, Order=(2, 0, 1) ,r2=-0.4405362182527357
# 1500    101.526720
# 1501    110.106999
# 1502    115.174982
# 1503    118.168411
# 1504    119.936495
#            ...
# 2004    122.487709
# 2005    122.487709
# 2006    122.487709
# 2007    122.487709
# 2008    122.487709
# Name: predicted_mean, Length: 509, dtype: float64
# Trend=n, Order=(1, 1, 1) ,r2=-0.6459179353783089
# 1500    171.949243
# 1501    172.063876
# 1502    172.178508
# 1503    172.293141
# 1504    172.407774
#            ...
# 2004    229.724188
# 2005    229.838821
# 2006    229.953454
# 2007    230.068087
# 2008    230.182720
# Name: predicted_mean, Length: 509, dtype: float64
# Trend=t, Order=(0, 0, 0) ,r2=-9.10667903234865
# 1500    125.034324
# 1501    171.972491
# 1502    172.087063
# 1503    172.201635
# 1504    172.316207
#            ...
# 2004    229.602180
# 2005    229.716752
# 2006    229.831324
# 2007    229.945896
# 2008    230.060468
# Name: predicted_mean, Length: 509, dtype: float64
# Trend=t, Order=(0, 0, 1) ,r2=-9.079440870859743
# 1500    101.615638
# 1501    110.057053
# 1502    114.939200
# 1503    117.769543
# 1504    119.417100
#            ...
# 2004    148.463194
# 2005    148.530085
# 2006    148.597018
# 2007    148.663993
# 2008    148.731011
# Name: predicted_mean, Length: 509, dtype: float64
# Trend=t, Order=(2, 0, 1) ,r2=-1.386596601017522
# 1500    101.127840
# 1501    109.479869
# 1502    114.413513
# 1503    117.324001
# 1504    119.037090
#            ...
# 2004    108.040194
# 2005    108.009302
# 2006    107.978396
# 2007    107.947473
# 2008    107.916536
# Name: predicted_mean, Length: 509, dtype: float64
# Trend=t, Order=(1, 1, 1) ,r2=-0.3246840660181829
# 1500    126.102413
# 1501    126.102413
# 1502    126.102413
# 1503    126.102413
# 1504    126.102413
#            ...
# 2004    126.102413
# 2005    126.102413
# 2006    126.102413
# 2007    126.102413
# 2008    126.102413
# Name: predicted_mean, Length: 509, dtype: float64
# Trend=c, Order=(0, 0, 0) ,r2=-0.8177724908589707
# 1500    104.807741
# 1501    126.099379
# 1502    126.099379
# 1503    126.099379
# 1504    126.099379
#            ...
# 2004    126.099379
# 2005    126.099379
# 2006    126.099379
# 2007    126.099379
# 2008    126.099379
# Name: predicted_mean, Length: 509, dtype: float64
# Trend=c, Order=(0, 0, 1) ,r2=-0.8152342902659804
# C:\Users\Admin\anaconda3\envs\aitd\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 1500     99.493298
# 1501    106.280605
# 1502    110.030972
# 1503    112.162752
# 1504    113.429740
#            ...
# 2004    122.935901
# 2005    122.935901
# 2006    122.935901
# 2007    122.935901
# 2008    122.935901
# Name: predicted_mean, Length: 509, dtype: float64
# Trend=c, Order=(2, 0, 1) ,r2=-0.6594018763402363
# 1500    100.929146
# 1501    109.154505
# 1502    114.005787
# 1503    116.861133
# 1504    118.535782
#            ...
# 2004    103.346310
# 2005    103.310978
# 2006    103.275646
# 2007    103.240314
# 2008    103.204982
# Name: predicted_mean, Length: 509, dtype: float64
# Trend=c, Order=(1, 1, 1) ,r2=-0.22730185077566833
# 1500    91.569963
# 1501    91.523941
# 1502    91.477918
# 1503    91.431895
# 1504    91.385872
#           ...
# 2004    68.374403
# 2005    68.328380
# 2006    68.282357
# 2007    68.236334
# 2008    68.190312
# Name: predicted_mean, Length: 509, dtype: float64
# Trend=ct, Order=(0, 0, 0) ,r2=-0.07528909495250002
# 1500    83.705089
# 1501    92.530728
# 1502    92.486731
# 1503    92.442735
# 1504    92.398738
#           ...
# 2004    70.400324
# 2005    70.356327
# 2006    70.312330
# 2007    70.268334
# 2008    70.224337
# Name: predicted_mean, Length: 509, dtype: float64
# Trend=ct, Order=(0, 0, 1) ,r2=-0.048113866109616765
# 1500    91.730730
# 1501    91.386137
# 1502    91.274506
# 1503    91.177307
# 1504    91.095855
#           ...
# 2004    67.649279
# 2005    67.602543
# 2006    67.555806
# 2007    67.509069
# 2008    67.462332
# Name: predicted_mean, Length: 509, dtype: float64
# Trend=ct, Order=(2, 0, 1) ,r2=-0.08580689587530221
# 1500    102.906700
# 1501    112.460229
# 1502    118.214262
# 1503    121.696052
# 1504    123.818991
#            ...
# 2004    204.585454
# 2005    204.795759
# 2006    205.006283
# 2007    205.217026
# 2008    205.427988
# Name: predicted_mean, Length: 509, dtype: float64
# Trend=ct, Order=(1, 1, 1) ,r2=-4.136526940690437

# %%
rscorelist
# Out:
# [-6.410263024207206,
#  -6.405887104311597,
#  -0.4405362182527357,
#  -0.6459179353783089,
#  -9.10667903234865,
#  -9.079440870859743,
#  -1.386596601017522,
#  -0.3246840660181829,
#  -0.8177724908589707,
#  -0.8152342902659804,
#  -0.6594018763402363,
#  -0.22730185077566833,
#  -0.07528909495250002,
#  -0.048113866109616765,
#  -0.08580689587530221,
#  -4.136526940690437]

# %%
result=pd.DataFrame()

# %%
result.insert(0,"Trend",trendslist)
result.insert(1,"Order",orderslist)
result.insert(2,"R_score",rscorelist)

# %%
result
# Out:
#    Trend      Order   R_score
# 0      n  (0, 0, 0) -6.410263
# 1      n  (0, 0, 1) -6.405887
# 2      n  (2, 0, 1) -0.440536
# 3      n  (1, 1, 1) -0.645918
# 4      t  (0, 0, 0) -9.106679
# 5      t  (0, 0, 1) -9.079441
# 6      t  (2, 0, 1) -1.386597
# 7      t  (1, 1, 1) -0.324684
# 8      c  (0, 0, 0) -0.817772
# 9      c  (0, 0, 1) -0.815234
# 10     c  (2, 0, 1) -0.659402
# 11     c  (1, 1, 1) -0.227302
# 12    ct  (0, 0, 0) -0.075289
# 13    ct  (0, 0, 1) -0.048114
# 14    ct  (2, 0, 1) -0.085807
# 15    ct  (1, 1, 1) -4.136527

# %%
model_fit.predict(len(data), len(data)+5)
# Out:
# 2009    205.639168
# 2010    205.850567
# 2011    206.062185
# 2012    206.274022
# 2013    206.486077
# 2014    206.698351
# Name: predicted_mean, dtype: float64
