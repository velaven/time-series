# %%
# !pip install nsepy
# Out:
# Requirement already satisfied: nsepy in c:\users\admin\anaconda3\envs\aids\lib\site-packages (0.8)
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from nsepy) (4.14.3)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from nsepy) (2.32.5)
# Requirement already satisfied: numpy in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from nsepy) (1.22.4)
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from nsepy) (2.1.4)
# Requirement already satisfied: six in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from nsepy) (1.17.0)
# Requirement already satisfied: click in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from nsepy) (8.1.8)
# Requirement already satisfied: lxml in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from nsepy) (6.0.2)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from beautifulsoup4->nsepy) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from beautifulsoup4->nsepy) (4.7.1)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from click->nsepy) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from pandas->nsepy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from pandas->nsepy) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from pandas->nsepy) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from requests->nsepy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from requests->nsepy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from requests->nsepy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from requests->nsepy) (2025.10.5)

# %%
import pandas as pd
class Descriptive():
    def init(self):
        pass
    def segreQuanQual(self,dataset):
        quantative=[]
        qualtative=[]

        for i in dataset.columns:
  
            if(dataset[i].dtypes =='object'):
                qualtative.append(i)
            else:
                quantative.append(i)
        print("The Quantitative Data:",quantative)
        print("The Qualtitative Data",qualtative)
        return quantative,qualtative
    def descriptive_Analysis(self,dataset,quantative):
        import pandas as pd
        des_data=pd.DataFrame(index=["Null_count","NonNull_count","Total_Count","Mean","Median","Mode","Std","Min","Q1:25%","Q2:50%","Q3:75%","Q4:100%","IQR","1.5Rule",
                            "Lesser","Greater"],columns=quantative)

        for i in quantative:
            des_data[i]["Null_count"]=dataset[i].isnull().sum()
            des_data[i]["NonNull_count"]=dataset[i].count()
            des_data[i]["Total_Count"]=len(dataset[i])
            des_data[i]["Mean"]=dataset[i].mean()
            des_data[i]["Median"]=dataset[i].median()
            des_data[i]["Mode"]=dataset[i].mode()[0]
            des_data[i]["Std"]=dataset[i].describe()["std"]
            des_data[i]["Min"]=dataset[i].describe()["min"]
            des_data[i]["Q1:25%"]=dataset[i].describe()["25%"]
            des_data[i]["Q2:50%"]=dataset[i].describe()["50%"]
            des_data[i]["Q3:75%"]=dataset[i].describe()["75%"]
            des_data[i]["Q4:100%"]=dataset[i].describe()["max"]
            des_data[i]["IQR"]=des_data[i]["Q3:75%"]-des_data[i]["Q1:25%"]
            des_data[i]["1.5Rule"]=1.5* des_data[i]["IQR"]
            des_data[i]["Lesser"]= des_data[i]["Q1:25%"]-des_data[i]["1.5Rule"]
            des_data[i]["Greater"]= des_data[i]["Q3:75%"]+des_data[i]["1.5Rule"]
        return des_data
    
    def outliercolumn(self,quantative,des_data):
        lesser=[]
        greater=[]

        for i in quantative:
            if(des_data[i]["Lesser"]>des_data[i]['Min']):
                lesser.append(i)
            if(des_data[i]['Greater']<des_data[i]['Q4:100%']):
                greater.append(i)

        print("Lesser Range",lesser)
        print("Greater Range",greater)
        return lesser,greater

    def changeoutlier(self,dataset,des_Data,lesser,greater):
        for i in lesser:
            dataset[i][dataset[i]<des_Data[i]['Lesser']]=des_Data[i]['Lesser']
        #print(dataset[i])
        for j in greater:
            dataset[j][dataset[j]>des_Data[j]['Greater']]=des_Data[j]['Greater']
        return des_Data

# %%
obj=Descriptive()

# %%
#!pip install --upgrade yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\admin\anaconda3\envs\aids\lib\site-packages (1.0)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from yfinance) (2.1.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from yfinance) (1.22.4)
# Requirement already satisfied: requests>=2.31 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from yfinance) (4.4.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from yfinance) (3.19.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from yfinance) (6.33.4)
# Requirement already satisfied: websockets>=13.0 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2025.10.5)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.7.1)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\envs\aids\lib\site-packages (from requests>=2.31->yfinance) (2.6.3)

# %%
from typing import Any,list, Union
class CalendarQuery:
    def_init_(self, operator: str, operand: List[Union[Any, "CalendarQuery"]]):
       self.operator = operator.upper()
       self.operand = operand
# Out:
#   Cell In[19], line 3
#     def_init_(self, operator: str, operand: List[Union[Any, "CalendarQuery"]]):
#                             ^
# SyntaxError: invalid syntax

# %%
import yfinance as yf
import datetime as dt
start = dt.datetime(2021,6,1).strftime('%Y-%m-%d')                       
end = dt.datetime(2022,1,5).strftime('%Y-%m-%d')
stK_data = yf.download('TATACOFFEE',start=start,end=end)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import yfinance as yf
#       2 import datetime as dt
#       3 start = dt.datetime(2021,6,1).strftime('%Y-%m-%d')
#
# File ~\anaconda3\envs\aids\lib\site-packages\yfinance\__init__.py:26
#      24 from .lookup import Lookup
#      25 from .ticker import Ticker
# ---> 26 from .calendars import Calendars
#      27 from .tickers import Tickers
#      28 from .multi import download
#
# File ~\anaconda3\envs\aids\lib\site-packages\yfinance\calendars.py:16
#      12 from .data import YfData
#      13 from .exceptions import YFException
# ---> 16 class CalendarQuery:
#      17     """
#      18     Simple CalendarQuery class for calendar queries, similar to yf.screener.query.QueryBase.
#      19
#    (...)
#      30     ```
#      31     """
#      33     def __init__(self, operator: str, operand: list[Any] | list["CalendarQuery"]):
#
# File ~\anaconda3\envs\aids\lib\site-packages\yfinance\calendars.py:33, in CalendarQuery()
#      16 class CalendarQuery:
#      17     """
#      18     Simple CalendarQuery class for calendar queries, similar to yf.screener.query.QueryBase.
#      19
#    (...)
#      30     ```
#      31     """
# ---> 33     def __init__(self, operator: str, operand: list[Any] | list["CalendarQuery"]):
#      34         """
#      35         :param operator: Operator string, e.g., 'eq', 'gte', 'and', 'or'.
#      36         :param operand: List of operands: can be values (str, int), or other Operands instances (nested).
#      37         """
#      38         operator = operator.upper()
#
# TypeError: unsupported operand type(s) for |: 'types.GenericAlias' and 'types.GenericAlias'
