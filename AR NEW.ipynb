# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#!pip install scikit-learn==1.0.0

# %%
#!pip install statsmodels==0.12.2   #conda update --all

# %%
#!pip install --upgrade numpy pandas

# %%
#!pip uninstall pandas -y

# %%
#!pip install pandas

# %%
from nsepy import get_history as gh
import datetime as dt
import yfinance as yf
stock_symbol = "RELIANCE.NS" #NSE stocks usually end with .NS
# Download stock data
stk_data = yf.download(stock_symbol, start="2023-01-01", end="2023-07-01")
# Out:
# C:\Users\Admin\anaconda3\envs\aitd\Lib\site-packages\yfinance\scrapers\history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*********************100%***********************]  1 of 1 completed

# %%
stk_data
# Out:
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2023-01-02  1175.889648  1177.304802  1163.244669  1164.066352     5316175
# 2023-01-03  1167.284668  1174.565828  1163.062148  1170.936659     7658932
# 2023-01-04  1149.709595  1169.110728  1147.632506  1167.261851     9264891
# 2023-01-05  1147.655273  1157.858026  1143.067494  1151.969199    13637099
# 2023-01-06  1158.086304  1163.130627  1149.595501  1153.407240     6349597
# ...                 ...          ...          ...          ...         ...
# 2023-06-23  1147.974976  1156.488600  1146.719570  1154.434333     6628570
# 2023-06-26  1139.210205  1148.271658  1136.083222  1144.437098    12641159
# 2023-06-27  1139.621094  1145.578264  1135.147420  1139.666736     9689466
# 2023-06-28  1154.708252  1158.519991  1140.260037  1147.176059    11354006
# 2023-06-30  1164.180542  1167.102135  1156.511422  1162.423070    11151555
#
# [122 rows x 5 columns]

# %%
stk_data=stk_data[["Open","High","Low","Close"]]

# %%
stk_data
# Out:
# Price              Open         High          Low        Close
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS
# Date
# 2023-01-02  1164.066352  1177.304802  1163.244669  1175.889648
# 2023-01-03  1170.936659  1174.565828  1163.062148  1167.284668
# 2023-01-04  1167.261851  1169.110728  1147.632506  1149.709595
# 2023-01-05  1151.969199  1157.858026  1143.067494  1147.655273
# 2023-01-06  1153.407240  1163.130627  1149.595501  1158.086304
# ...                 ...          ...          ...          ...
# 2023-06-23  1154.434333  1156.488600  1146.719570  1147.974976
# 2023-06-26  1144.437098  1148.271658  1136.083222  1139.210205
# 2023-06-27  1139.666736  1145.578264  1135.147420  1139.621094
# 2023-06-28  1147.176059  1158.519991  1140.260037  1154.708252
# 2023-06-30  1162.423070  1167.102135  1156.511422  1164.180542
#
# [122 rows x 4 columns]

# %%
column="Close"

# %%
from sklearn.preprocessing import MinMaxScaler
Ms = MinMaxScaler()
data1= Ms.fit_transform(stk_data[[column]])
print("Len:",data1.shape)
# Out:
# Len: (122, 1)

# %%
len(data1)
# Out:
# 122

# %%
training_size = round(len(data1 ) * 0.80)
print(training_size)
X_train=data1[:training_size]
X_test=data1[training_size:]
print("X_train length:",X_train.shape)
print("X_test length:",X_test.shape)
y_train=data1[:training_size]
y_test=data1[training_size:]
print("y_train length:",y_train.shape)
print("y_test length:",y_test.shape)
# Out:
# 98
# X_train length: (98, 1)
# X_test length: (24, 1)
# y_train length: (98, 1)
# y_test length: (24, 1)

# %%
#!pip install --upgrade scikit-learn

# %%
from sklearn.metrics import mean_squared_error
trends=['n','t','c','ct']
lags=[1,2,3,4]
from statsmodels.tsa.ar_model import AutoReg
for i in lags:
    #print(i)
   
    for td in trends:
        
        #print(td)
        #trendslist.append(td)
        model = AutoReg(X_train, lags=i,trend=td)
        model_fit = model.fit()
        # make prediction
        y_pred= model_fit.predict(len(X_train), len(data1)-1)
        #print(y_pred)
        #mse=mean_squared_error(y_test,y_pred,squared=False)
        from stockFunctions import rmsemape
        print("Lag={},Trend={}".format(i,td))
        rmsemape(y_test,y_pred)
        print("************")
# Out:
# Lag=1,Trend=n
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 20
#      18 from stockFunctions import rmsemape
#      19 print("Lag={},Trend={}".format(i,td))
# ---> 20 rmsemape(y_test,y_pred)
#      21 print("************")
#
# File ~\Time series\TimeSeriesAnalysis\TimeSeriesAnalysis\3.TS-Model\1.AR\stockFunctions.py:22, in rmsemape(y_Test, predicted_stock_price_test_ori)
#      20 def rmsemape(y_Test,predicted_stock_price_test_ori):
#      21     from sklearn.metrics import mean_squared_error
# ---> 22     print("RMSE-Testset:",mean_squared_error(y_Test,predicted_stock_price_test_ori,squared=False))
#      23     #print("RMSE-Trainset:",mean_squared_error(y_Train,predicted_stock_price_train_ori,squared=False))
#      24     from sklearn.metrics import mean_absolute_percentage_error
#
# File ~\anaconda3\envs\aitd\Lib\site-packages\sklearn\utils\_param_validation.py:196, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
# --> 196 params = func_sig.bind(*args, **kwargs)
#     197 params.apply_defaults()
#     199 # ignore self/cls and positional/keyword markers
#
# File ~\anaconda3\envs\aitd\Lib\inspect.py:3280, in Signature.bind(self, *args, **kwargs)
#    3275 def bind(self, /, *args, **kwargs):
#    3276     """Get a BoundArguments object, that maps the passed `args`
#    3277     and `kwargs` to the function's signature.  Raises `TypeError`
#    3278     if the passed arguments can not be bound.
#    3279     """
# -> 3280     return self._bind(args, kwargs)
#
# File ~\anaconda3\envs\aitd\Lib\inspect.py:3269, in Signature._bind(self, args, kwargs, partial)
#    3259         raise TypeError(
#    3260             'got some positional-only arguments passed as '
#    3261             'keyword arguments: {arg!r}'.format(
#    (...)   3266             ),
#    3267         )
#    3268     else:
# -> 3269         raise TypeError(
#    3270             'got an unexpected keyword argument {arg!r}'.format(
#    3271                 arg=next(iter(kwargs))))
#    3273 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'squared'

# %%
len(y_pred)

# %%
i=1
td='ct'
model = AutoReg(X_train, lags=i,trend=td)
model_fit = model.fit()
# make prediction
y_pred= model_fit.predict(len(X_train), len(data1)-1)
#print(y_pred)
from sklearn.metrics import r2_score
mse=mean_squared_error(y_test,y_pred,squared=False)
from stockFunctions import rmsemape
print("Lag={},Trend={}".format(i,td))
rmse = mean_square_error(y_true, y_pred, squared=False)
print("************")
